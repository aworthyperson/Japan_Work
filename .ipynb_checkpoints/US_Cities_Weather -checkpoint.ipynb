# %% [markdown]
# ## This notebook will pull in Solar and Weather data for US Cities from the NSRDB: National Solar Radiation Database
#
#
# By Amanda Worthy

# %% [markdown]
# Data Viewer: https://nsrdb.nrel.gov/data-viewer
#
# Discription of Dataset: https://nsrdb.nrel.gov/data-sets/us-data
#
#
# Weather Varriables Needed:
# - Wind Speed (Meter per second)
# - Precipitable Water (Millimeter)
# - Temperature (Degree C)
# - GHI (Watt per square meter)
# - Clearsky GHI (Watt per square meter)
# - Cloud Type
#
# ![Screen%20Shot%202023-07-19%20at%2012.31.50%20PM.png](attachment:Screen%20Shot%202023-07-19%20at%2012.31.50%20PM.png)
#
#
# Cities Examined:
# - Seattle, WA
# - Denver, CO
# - Miami, FL
#
# Weather data is from 2021, in UTC time
