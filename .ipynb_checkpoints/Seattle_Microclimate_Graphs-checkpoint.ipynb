# %%
#import packages
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, box
import fiona
import pyproj
import contextily as ctx
import os
import requests
import matplotlib.ticker as ticker

#import packages 
import os
from glob import glob
import numpy as np
import xarray as xr
import pandas as pd
import geopandas as gpd
#import cartopy.crs as ccrs

#%matplotlib widget
# %matplotlib inline

#import earthpy as et
#from adjustText import adjust_text

# %%
#https://cds.climate.copernicus.eu/cdsapp#!/yourrequests?tab=form

# %%
#install adjust text
# !pip install -q https://github.com/Phlya/adjustText/archive/master.zip

# %%
# !pwd
# !ls
# Out:
# /Users/amandaworthy/Japan_work
# City_Clerk_Neighborhoods.geojson  Seattle_Microclimate_Graphs.ipynb
# Denver_weather.xlsx               Seattle_shape_files
# NSRDB_data                        Seattle_weather.xlsx
# Precipitation_data                US_Cities_Weather.ipynb
# README.md                         denvertest.csv

# %%
# !ls
# !ls Seattle_shape_files
# Out:
# City_Clerk_Neighborhoods.geojson  Seattle_Microclimate_Graphs.ipynb
# Denver_weather.xlsx               Seattle_shape_files
# NSRDB_data                        Seattle_weather.xlsx
# Precipitation_data                US_Cities_Weather.ipynb
# README.md                         denvertest.csv
# City_Clerk_Neighborhoods.cpg City_Clerk_Neighborhoods.shp
# City_Clerk_Neighborhoods.dbf City_Clerk_Neighborhoods.shx
# City_Clerk_Neighborhoods.prj

# %%
shp_fn = 'Seattle_shape_files/City_Clerk_Neighborhoods.shp'
shp_gdf = gpd.read_file(shp_fn)
shp_gdf.plot();

# %%
seattle_gdf = gpd.read_file('City_Clerk_Neighborhoods.geojson')
ax = seattle_gdf.plot(color='blue')

newshape= seattle_gdf.squeeze().geometry
newshape
# Out:
# 0      POLYGON ((-122.27398 47.69523, -122.27407 47.6...
# 1      POLYGON ((-122.28756 47.64523, -122.28754 47.6...
# 2      POLYGON ((-122.39529 47.66514, -122.39540 47.6...
# 3      POLYGON ((-122.39832 47.66609, -122.39830 47.6...
# 4      POLYGON ((-122.28851 47.65630, -122.28847 47.6...
#                              ...
# 114    POLYGON ((-122.34470 47.70505, -122.34469 47.7...
# 115    POLYGON ((-122.33001 47.70864, -122.32994 47.7...
# 116    POLYGON ((-122.36607 47.70517, -122.36747 47.7...
# 117    POLYGON ((-122.36077 47.70512, -122.36099 47.7...
# 118    POLYGON ((-122.40211 47.69768, -122.40220 47.6...
# Name: geometry, Length: 119, dtype: geometry

# %%
newshape
# Out:
# 0      POLYGON ((-122.27398 47.69523, -122.27407 47.6...
# 1      POLYGON ((-122.28756 47.64523, -122.28754 47.6...
# 2      POLYGON ((-122.39529 47.66514, -122.39540 47.6...
# 3      POLYGON ((-122.39832 47.66609, -122.39830 47.6...
# 4      POLYGON ((-122.28851 47.65630, -122.28847 47.6...
#                              ...
# 114    POLYGON ((-122.34470 47.70505, -122.34469 47.7...
# 115    POLYGON ((-122.33001 47.70864, -122.32994 47.7...
# 116    POLYGON ((-122.36607 47.70517, -122.36747 47.7...
# 117    POLYGON ((-122.36077 47.70512, -122.36099 47.7...
# 118    POLYGON ((-122.40211 47.69768, -122.40220 47.6...
# Name: geometry, Length: 119, dtype: geometry

# %%
outdir = '/Users/amandaworthy/Norway_sport_facility/Energy_consumption_of_sport_facilities_in_norway/climate_data'
t_mean_fn = os.path.join(outdir, '1month_mean_Global_ea_2t.nc')
t_mean_ds = xr.open_dataset(t_mean_fn)

# %%
def ds_swaplon(ds):
    return ds.assign_coords(longitude=(((ds.longitude + 180) % 360) - 180)).sortby('longitude')



t_mean_ds = ds_swaplon(t_mean_ds)

# %%
t_mean_ds2021 = t_mean_ds.sel(time=slice("2020-01-01", "2020-12-31"))

# %%
t_mean_ds2021
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 12, latitude: 721, longitude: 1440)
# Coordinates:
#   * time       (time) datetime64[ns] 2020-01-01 2020-02-01 ... 2020-12-01
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
# Data variables:
#     t2m        (time, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-02-28T08:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
t_mean_ds2021['t2m'].mean(dim=('latitude', 'longitude')).plot();

# %%
seattle_bounds
# Out:
# array([-122.4359559 ,   47.49551362, -122.23604445,   47.73416495])

# %%
seattle_bounds = newshape.total_bounds
seattle_bounds

def myround(x, base=0.25):
    return base * np.round(x/base)

def roundbounds(bounds, base=0.25):
    bounds_floor = np.floor(bounds/base)*base
    bounds_ceil = np.ceil(bounds/base)*base
    return [bounds_floor[0]-.2, bounds_floor[1]-.2, bounds_ceil[2]+.2, bounds_ceil[3]]

# %%
seattle_rbounds = roundbounds(seattle_bounds)
seattle_rbounds

seattle_bounds= []

# %%
t_mean_ds2021_seattle = t_mean_ds2021.sel(latitude=slice(seattle_rbounds[3],seattle_rbounds[1]), longitude=slice(seattle_rbounds[0],seattle_rbounds[2]))


t_mean_ds2021_seattle['Average Temperature in 2021 (c)']= t_mean_ds2021_seattle['t2m']- 273.15
t_mean_ds2021_seattle
# Out:
# <xarray.Dataset>
# Dimensions:                          (time: 12, latitude: 3, longitude: 3)
# Coordinates:
#   * time                             (time) datetime64[ns] 2020-01-01 ... 202...
#   * latitude                         (latitude) float64 47.75 47.5 47.25
#   * longitude                        (longitude) float64 -122.5 -122.2 -122.0
# Data variables:
#     t2m                              (time, latitude, longitude) float32 280....
#     Average Temperature in 2021 (c)  (time, latitude, longitude) float32 6.93...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-02-28T08:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
t_mean_ds2021_seattle['Average Temperature in 2021 (c)'].max()
# Out:
# <xarray.DataArray 'Average Temperature in 2021 (c)' ()>
# array(19.306183, dtype=float32)

# %%
import cartopy.crs as ccrs

# %%
newshape.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.head(70)

idx = (world['name']=='United States of America') 
US= world[idx]
ax= US.plot(aspect= 'equal')
ax.set_title("US Plot");

# %%
t_mean_ds2021_seattle
# Out:
# <xarray.Dataset>
# Dimensions:                          (time: 12, latitude: 3, longitude: 3)
# Coordinates:
#   * time                             (time) datetime64[ns] 2020-01-01 ... 202...
#   * latitude                         (latitude) float64 47.75 47.5 47.25
#   * longitude                        (longitude) float64 -122.5 -122.2 -122.0
# Data variables:
#     t2m                              (time, latitude, longitude) float32 280....
#     Average Temperature in 2021 (c)  (time, latitude, longitude) float32 6.93...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2022-02-28T08:01 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
t_mean_ds2021_seattle.rio.write_crs(world.crs, inplace=True);
t_mean_ds2019_seattle_land = t_mean_ds2021_seattle['Average Temperature in 2021 (c)'].rio.clip(world.geometry, crs=world.crs, drop=False)

# %%
t_mean_ds2019_seattle_land.isel(time=0).isnull().plot();

# %%
world.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
shp_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
world.geometry
# Out:
# 0      MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1      POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2      POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3      MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
#                              ...
# 172    POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173    POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174    POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175    POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176    POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
# Name: geometry, Length: 177, dtype: geometry

# %%
shp_gdf.geometry
# Out:
# 0      POLYGON ((-122.27398 47.69523, -122.27409 47.6...
# 1      POLYGON ((-122.28756 47.64523, -122.28754 47.6...
# 2      POLYGON ((-122.39529 47.66514, -122.39520 47.6...
# 3      POLYGON ((-122.39832 47.66609, -122.39824 47.6...
# 4      POLYGON ((-122.28851 47.65630, -122.28847 47.6...
#                              ...
# 114    POLYGON ((-122.34470 47.70505, -122.33920 47.7...
# 115    POLYGON ((-122.33001 47.70864, -122.32967 47.7...
# 116    POLYGON ((-122.36607 47.70517, -122.36607 47.7...
# 117    POLYGON ((-122.36077 47.70512, -122.35913 47.7...
# 118    POLYGON ((-122.40211 47.69768, -122.40203 47.6...
# Name: geometry, Length: 119, dtype: geometry

# %%
t_mean_ds2021_seattle.rio.write_crs(world.crs, inplace=True);


t_mean_ds2021_seattle_land = t_mean_ds2021_seattle['Average Temperature in 2021 (c)'].rio.clip(world.geometry, crs=world.crs, drop=False)

# %%
t_mean_ds2021_seattle_land.isel(time=0).isnull().plot();

# %%
f, ax = plt.subplots(figsize=(12,9))

#add data to plot
t_mean_ds2021_seattle_land.mean(dim='time').plot(ax=ax, cmap='inferno', alpha=.8, vmin=-10, vmax=10, label= 'this')#, clim=(-50,50));
shp_gdf.plot(ax=ax,edgecolor='k', facecolor='none', linewidth=.3);
